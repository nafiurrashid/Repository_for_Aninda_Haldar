# %%
'''
Task 1 : Go to kaggle and download any dataset, do some analysis and visualization .
Write a short summary about your findings .
'''
# Out:
# '\nTask 1 : Go to kaggle and download any dataset, do some analysis and visualization .\nWrite a short summary about your findings .\n'

# %%
#NR
#
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
ca = pd.read_csv('Weather.csv')

# %%
ca.describe()
# Out:
#               tempm         tempi        dewptm        dewpti           hum  \
# count  10476.000000  10476.000000  10476.000000  10476.000000  10476.000000
# mean      13.705622     56.670151      5.957961     42.723759     62.685949
# std        9.521071     17.138025     10.629692     19.133455     20.000169
# min      -18.300000     -0.900000    -28.300000    -18.900000      9.000000
# 25%        6.100000     43.000000     -2.200000     28.000000     47.000000
# 50%       13.300000     55.900000      6.700000     44.100000     61.000000
# 75%       21.700000     71.100000     15.000000     59.000000     81.000000
# max       35.600000     96.100000     25.600000     78.100000    100.000000
#
#              wspdm        wspdi       wgustm       wgusti         wdird  ...  \
# count  9744.000000  9744.000000  1876.000000  1876.000000  10481.000000  ...
# mean      8.690004     5.410324    34.969243    21.744296     80.298636  ...
# ...

# %%
df.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1051A130>,
# ...
#       dtype=object)

# %%
fig = plt.figure()
# x axis values 
x = ca.hum
# corresponding y axis values 
y = ca.fog
plt.subplot(2, 2, 1)
plt.plot(x, y)
# x axis values 
x = ca.hum
# corresponding y axis values 
y = ca.precipi

plt.subplot(2, 2, 2)
plt.plot(x, y)

# x axis values 
x = ca.vism
# corresponding y axis values 
y = ca.fog
plt.subplot(2, 2, 3)
plt.plot(x, y)
# x axis values 
x = ca.hum
# corresponding y axis values 
y = ca.windchillm


plt.subplot(2, 2, 4)
plt.plot(x, y)

plt.show()

# %%
'''
Findings: These graphs are showing the fact that
1. High humidity creates fog
2. High humidity causes high Precipitation(in inches)
3.Visibility is proportionate to fog
'''
# Out:
# '\nFindings: These graphs are showing the fact that\n'
